# %%
import pandas as pd
# import numpy as np
from sklearn.preprocessing import StandardScaler
import joblib

# %%
df = pd.read_csv("../dataset/smogn_syn_data.csv")

# %%
tar_col = "LC50 [-LOG(mol/L)]"
isSyn = "isSyn"
temp_df = df.drop([tar_col, isSyn], axis=1)

# %%
scl = StandardScaler()
scaled_df = scl.fit_transform(temp_df)
scaled_df = pd.DataFrame(scaled_df, columns = temp_df.columns)
scaled_df
# Out:
#           CIC0  SM1_Dz(Z)    GATS1i     NdsCH     NdssC     MLOGP
# 0     0.475114   0.462952  0.929225 -0.376427  0.588831 -0.437628
# 1    -0.936239  -0.112078 -1.083945 -0.376427 -0.560996 -0.509101
# 2    -1.020577   0.021865 -1.163184 -0.376427 -0.560996 -0.509101
# 3     0.168069  -0.687108  0.424076  1.266997 -0.560996 -0.196661
# 4    -1.061429   0.458333 -1.091373 -0.376427 -0.560996 -0.142886
# ...        ...        ...       ...       ...       ...       ...
# 1069  0.123265   0.421383 -0.170218 -0.376427  1.738658 -1.466842
# 1070  0.245819   0.737765 -1.361282 -0.376427 -0.560996  1.014299
# 1071  0.547593  -0.936518 -1.242423 -0.376427 -0.560996  0.701859
# 1072 -1.235377   1.654579 -1.282043 -0.376427 -0.560996  1.035400
# 1073 -0.161378  -0.158265 -0.430222  1.266997 -0.560996 -0.451242
#
# [1074 rows x 6 columns]

# %%
scaled_df[tar_col] = df[tar_col]
scaled_df[isSyn] = df[isSyn]

# %%
scaled_df
# Out:
#           CIC0  SM1_Dz(Z)    GATS1i     NdsCH     NdssC     MLOGP  \
# 0     0.475114   0.462952  0.929225 -0.376427  0.588831 -0.437628
# 1    -0.936239  -0.112078 -1.083945 -0.376427 -0.560996 -0.509101
# 2    -1.020577   0.021865 -1.163184 -0.376427 -0.560996 -0.509101
# 3     0.168069  -0.687108  0.424076  1.266997 -0.560996 -0.196661
# 4    -1.061429   0.458333 -1.091373 -0.376427 -0.560996 -0.142886
# ...        ...        ...       ...       ...       ...       ...
# 1069  0.123265   0.421383 -0.170218 -0.376427  1.738658 -1.466842
# 1070  0.245819   0.737765 -1.361282 -0.376427 -0.560996  1.014299
# 1071  0.547593  -0.936518 -1.242423 -0.376427 -0.560996  0.701859
# 1072 -1.235377   1.654579 -1.282043 -0.376427 -0.560996  1.035400
# 1073 -0.161378  -0.158265 -0.430222  1.266997 -0.560996 -0.451242
#
#       LC50 [-LOG(mol/L)]  isSyn
# 0                  3.770      0
# 1                  3.115      0
# 2                  3.531      0
# 3                  3.510      0
# ...

# %%
scaled_df.to_csv("../dataset/std_scaled_df.csv",index=False)

# %%
joblib.dump(scl,"../exports/std_scaler.z")
# Out:
# ['../exports/std_scaler.z']
